# %%
import underworld

# %%
import numpy as np
blat = np.random.rand(10000).reshape(100, 100)

# %%
#thing = underworld.importers.NumpyVoxelField(ndarray=blat, minTup=(0,0), maxTup=(10,1))

# %%
import glucifer.pylab as plt

# %%
fig = plt.figure()

# %%
fig.Surface(ndarray=blat)

# %%
fig.show()
